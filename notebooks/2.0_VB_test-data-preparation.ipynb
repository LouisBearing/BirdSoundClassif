# %% [markdown]
# # Notebook to test the data preparation

# %% [markdown]
# In this notebook, VB tries to prepare some data from some wav files he could have

# %%
import os
os.chdir('C:/Users/User/Documents/Dev/Projets/BirdSoundClassif')

# %%
# OPTIONAL: Load the "autoreload" extension so that code can change
# %load_ext autoreload

# OPTIONAL: always reload modules so that as you change code in src, it gets loaded
# %autoreload 2

from detr.nbm_datasets.prepare_dataset import prepare_dataset

# %%
# Try to launch the function rawly
prepare_dataset(r"data\raw", r"data\interim")
# Out:
# C:\Users\User\Documents\Dev\Projets\BirdSoundClassif\detr\nbm_datasets\utils.py:158: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   labels['bird_id'].fillna(birds_dict['Other'], inplace=True)
# ~~~ Processing file anthus_hodgsoni#801634 ~~~
# ~~~ Processing file anthus_hodgsoni#824869 ~~~
# ~~~ Processing file anthus_hodgsoni#837468 ~~~

# %%
from detr.nbm_datasets.utils import visualise_file_annot

visualise_file_annot(r"data\interim\positive_files\raw__anthus_hodgsoni__755152")
